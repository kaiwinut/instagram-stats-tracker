# %%
from follower_tracker import get_user_info, get_media_info, display

# %%
path = 'data/info.txt'
user_info = get_user_info(path)
media_info = get_media_info(path)

# %%
user_info

# %%
media_info

# %%
display(media_info)
